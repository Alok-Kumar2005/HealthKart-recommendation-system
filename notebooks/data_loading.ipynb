# %%
print("hello world")
# Out:
# hello world

# %%
# https://drive.google.com/file/d/1ShhXrwl89sZmwddLg1H8eHyW0IlmyKhY/view?usp=sharing

# %%
# %pwd
# Out:
# 'c:\\Users\\Lenovo\\MLOPS\\HealthKart-recommendation-system\\notebooks'

# %%
## move one fodler back
import os
os.chdir("..")

# %%
# %pwd
# Out:
# 'c:\\Users\\Lenovo\\MLOPS\\HealthKart-recommendation-system'

# %%
import os
import gdown

# %%
DATA_DIR = "data"
FILE_ID = "1ShhXrwl89sZmwddLg1H8eHyW0IlmyKhY"
OUTPUT = os.path.join(DATA_DIR, "dataset.csv")

os.makedirs(DATA_DIR, exist_ok=True)

url = f"https://drive.google.com/uc?id={FILE_ID}"
gdown.download(url, OUTPUT, quiet=False)

print("Dataset downloaded successfully")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ShhXrwl89sZmwddLg1H8eHyW0IlmyKhY
# To: c:\Users\Lenovo\MLOPS\HealthKart-recommendation-system\data\dataset.csv
# 100%|██████████| 99.4M/99.4M [02:26<00:00, 679kB/s]
# ✅ Dataset downloaded successfully
